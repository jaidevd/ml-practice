# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer
import pandas as pd

# %%
clf = pipeline('ner', aggregation_strategy='simple')

# %%
clf('Hugging Face Inc. is a company based in New York City. Its headquarters are in DUMBO,therefore very close to the Manhattan Bridge which is visible from the window.')
# Out:
# [{'entity': 'I-ORG',
#   'score': 0.9995786,
#   'index': 1,
#   'word': 'Hu',
#   'start': 0,
#   'end': 2},
#  {'entity': 'I-ORG',
#   'score': 0.9909764,
#   'index': 2,
#   'word': '##gging',
#   'start': 2,
#   'end': 7},
#  {'entity': 'I-ORG',
#   'score': 0.9982225,
#   'index': 3,
#   'word': 'Face',
#   'start': 8,
#   'end': 12},
#  {'entity': 'I-ORG',
#   'score': 0.99948806,
#   'index': 4,
#   'word': 'Inc',
#   'start': 13,
#   'end': 16},
#  {'entity': 'I-LOC',
#   'score': 0.9994345,
#   'index': 11,
#   'word': 'New',
#   'start': 40,
#   'end': 43},
#  {'entity': 'I-LOC',
#   'score': 0.9993196,
#   'index': 12,
#   'word': 'York',
#   'start': 44,
#   'end': 48},
#  {'entity': 'I-LOC',
#   'score': 0.9993794,
#   'index': 13,
#   'word': 'City',
#   'start': 49,
#   'end': 53},
#  {'entity': 'I-LOC',
#   'score': 0.98625815,
#   'index': 19,
#   'word': 'D',
#   'start': 79,
#   'end': 80},
#  {'entity': 'I-LOC',
#   'score': 0.95142686,
#   'index': 20,
#   'word': '##UM',
#   'start': 80,
#   'end': 82},
#  {'entity': 'I-LOC',
#   'score': 0.9336589,
#   'index': 21,
#   'word': '##BO',
#   'start': 82,
#   'end': 84},
#  {'entity': 'I-LOC',
#   'score': 0.97616535,
#   'index': 28,
#   'word': 'Manhattan',
#   'start': 113,
#   'end': 122},
#  {'entity': 'I-LOC',
#   'score': 0.9914629,
#   'index': 29,
#   'word': 'Bridge',
#   'start': 123,
#   'end': 129}]

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples[f"ner_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)  # Map tokens to their respective word.
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:  # Set the special tokens to -100.
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:  # Only label the first token of a given word.
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

# %%
# parse the azure dataset

# %%
import json
ROOT = '/tmp/LoanAgreements/'

with open('/tmp/LoanAgreements/loanAgreementsLabels.json', 'r') as fin:
    anno = json.load(fin)

# %%
clf.model.config.label2id
# Out:
# {'B-LOC': 7,
#  'B-MISC': 1,
#  'B-ORG': 5,
#  'B-PER': 3,
#  'I-LOC': 8,
#  'I-MISC': 2,
#  'I-ORG': 6,
#  'I-PER': 4,
#  'O': 0}

# %%
labelmap = {
    'BorrowerName': 'PER',
    'BorrowerAddress': 'LOC',
    'BorrowerCity': 'LOC',
    'BorrowerState': 'LOC',
    'LenderName': 'PER',
    'LenderAddress': 'LOC',
    'LenderCity': 'LOC',
    'LenderState': 'LOC',
}

# %%
pred = []
for doc in anno['documents']:
    with open(ROOT + doc['location'], 'r') as fin:
        text = fin.read()
    pred.append({'text': text, 'id': doc['location'], 'predictions': clf(text)})

# %%
from spacy import load
nlp = load('en_core_web_sm')

# %%
doc = nlp(pred[0]['text'])

# %%
ent_true = []
for label in anno['documents'][0]['extractors'][0]['labels']:
    start = label['offset'] - 1
    end = start + label['length']
    print(doc.char_span(start, end + 1), labelmap.get(label['extractorName'], 'MISC'))
    ent_true.append((start, end, labelmap.get(label['extractorName'], 'MISC')))
# Out:
# Fusce Rd, City LOC
# None LOC
# None LOC
# None LOC
# None LOC
# None LOC
# None MISC
# None MISC
# None MISC
# None MISC
# None PER
# Williams with a PER

# %%
for label in anno['documents'][0]['extractors'][0]['labels']:
    start = label['offset'] - 1
    end = start + label['length'] + 1
    print(doc.char_span(start, end), label['extractorName'])
# Out:
# Fusce Rd, City BorrowerAddress
# None BorrowerCity
# None BorrowerState
# None LenderAddress
# None LenderCity
# None LenderState
# None LoanAmountWords
# None LoanAmountNumbers
# None Interest
# None Date
# None BorrowerName
# Williams with a LenderName

# %%
doc.text[199:214]
# Out:
# 'Fusce Rd, City '

# %%
doc.text[272:272 + 14]
# Out:
# 'Williams with '

# %%
label
# Out:
# {'extractorName': 'LenderName', 'offset': 273, 'length': 14}

# %%
anno['documents'][0]['extractors'][0]['labels']
# Out:
# [{'extractorName': 'BorrowerAddress', 'offset': 200, 'length': 13},
#  {'extractorName': 'BorrowerCity', 'offset': 223, 'length': 9},
#  {'extractorName': 'BorrowerState', 'offset': 243, 'length': 8},
#  {'extractorName': 'LenderAddress', 'offset': 314, 'length': 15},
#  {'extractorName': 'LenderCity', 'offset': 339, 'length': 10},
#  {'extractorName': 'LenderState', 'offset': 360, 'length': 8},
#  {'extractorName': 'LoanAmountWords', 'offset': 446, 'length': 66},
#  {'extractorName': 'LoanAmountNumbers', 'offset': 514, 'length': 11},
#  {'extractorName': 'Interest', 'offset': 601, 'length': 2},
#  {'extractorName': 'Date', 'offset': 5, 'length': 9},
#  {'extractorName': 'BorrowerName', 'offset': 160, 'length': 13},
#  {'extractorName': 'LenderName', 'offset': 273, 'length': 14}]

# %%
doc.text[199:(199 + 14)]
# Out:
# 'Fusce Rd, City'

# %%
doc.char_span(199, 213)
# Out:
# Fusce Rd, City

# %%
import pandas as pd

# %%
df = pd.read_csv('/tmp/ner.csv', usecols=['Sentence', 'Tag'])

# %%
df.head()
# Out:
#                                             Sentence  \
# 0  Thousands of demonstrators have marched throug...
# 1  Families of soldiers killed in the conflict jo...
# 2  They marched from the Houses of Parliament to ...
# 3  Police put the number of marchers at 10,000 wh...
# 4  The protest comes on the eve of the annual con...
#
#                                                  Tag
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...

# %%
print(df.iloc[0]['Sentence'])
# Out:
# Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .

# %%
df['Tag'][0]
# Out:
# "['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O', 'B-gpe', 'O', 'O', 'O', 'O', 'O']"

# %%
import ast

# %%
from tqdm import tqdm

# %%
df = df.sample(1000)
df.head()
# Out:
#                                                 Sentence  \
# 34213  The International Criminal Tribunal for the fo...
# 6007   In the Great Plains states of the country , wh...
# 30616  Pakistan and India often conduct such tests to...
# 1737   Iraq 's foreign minister says Syria is refusin...
# 42998                     VOA 's Chris Simkins reports .
#
#                                                      Tag
# 34213  ['B-org', 'I-org', 'I-org', 'I-org', 'O', 'O',...
# 6007   ['O', 'O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O...
# 30616  ['B-geo', 'O', 'B-geo', 'O', 'O', 'O', 'O', 'O...
# 1737   ['B-geo', 'O', 'O', 'O', 'O', 'B-geo', 'O', 'O...
# 42998         ['B-org', 'O', 'B-per', 'I-per', 'O', 'O']

# %%
pred = []
for text in tqdm(df['Sentence'].values):
    pred.append(clf(text))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:16<00:00, 13.06it/s]

# %%
pred[0]
# Out:
# [{'entity_group': 'ORG',
#   'score': 0.8809569,
#   'word': 'International Criminal Tribunal for',
#   'start': 4,
#   'end': 39},
#  {'entity_group': 'LOC',
#   'score': 0.999504,
#   'word': 'Yugoslavia',
#   'start': 51,
#   'end': 61},
#  {'entity_group': 'PER',
#   'score': 0.96618253,
#   'word': 'Perisic',
#   'start': 167,
#   'end': 174},
#  {'entity_group': 'ORG',
#   'score': 0.61537665,
#   'word': 'Staff',
#   'start': 212,
#   'end': 217},
#  {'entity_group': 'MISC',
#   'score': 0.73656905,
#   'word': 'Yugoslav',
#   'start': 225,
#   'end': 233},
#  {'entity_group': 'ORG',
#   'score': 0.9765235,
#   'word': 'Army',
#   'start': 234,
#   'end': 238}]

# %%
doc = nlp(df['Sentence'].iloc[0])

# %%
from spacy.training import offsets_to_biluo_tags

ent_pred_tags = []
for doc, ents in zip(df['Sentence'].values, pred):
    entities = [(k['start'], k['end'], k['entity_group']) for k in ents]
    tags = offsets_to_biluo_tags(nlp(doc), entities)
    ent_pred_tags.append(tags)

# %%
ent_true_tags = [ast.literal_eval(k.upper()) for k in df['Tag'].values]

# %%
from seqeval.metrics import classification_report, f1_score

# %%
print(classification_report(ent_true_tags[:2], ent_pred_tags[:2]))
# Out:
#               precision    recall  f1-score   support
#
#          GEO       0.00      0.00      0.00         2
#          GPE       0.00      0.00      0.00         1
#          LOC       0.00      0.00      0.00         0
#         MISC       0.00      0.00      0.00         0
#          ORG       0.33      0.25      0.29         4
#          PER       0.00      0.00      0.00         0
#          TIM       0.00      0.00      0.00         1
#
#    micro avg       0.14      0.12      0.13         8
#    macro avg       0.05      0.04      0.04         8
# weighted avg       0.17      0.12      0.14         8

# %%
f1_score(ent_true_tags[:2], ent_pred_tags[:2])
# Out:
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: L-ORG seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: U-LOC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: U-PER seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: U-ORG seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: U-MISC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /home/jaidevd/conda/lib/python3.7/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: L-LOC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# 0.13333333333333333

# %%
def replace_tags(tags):
    tags = [tag.replace('L-', 'I-') for tag in tags]
    tags = [tag.replace('U-', 'B-') for tag in tags]
    return tags

ent_pred_tags = [replace_tags(tag) for tag in ent_pred_tags]

# %%
f1_score(ent_true_tags[:2], ent_pred_tags[:2])
# Out:
# 0.13333333333333333

# %%
len(ent_true_tags)
# Out:
# 1000

# %%
len(ent_pred_tags)
# Out:
# 1000

# %%
count = 0
to_remove = []
for num, (i, j) in enumerate(zip(ent_true_tags, ent_pred_tags)):
    if len(i) != len(j):
        to_remove.append(num)

# %%
df.drop(df.index[to_remove], axis=0, inplace=True)

# %%
from spacy.training import offsets_to_biluo_tags

ent_pred_tags = []
for doc, ents in zip(df['Sentence'].values, pred):
    entities = [(k['start'], k['end'], k['entity_group']) for k in ents]
    tags = offsets_to_biluo_tags(nlp(doc), entities)
    ent_pred_tags.append(tags)
# Out:
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Television images showed hundreds of New Orleans r..." with entities "[(4, 13, 'MISC'), (39, 76, 'ORG'), (79, 82, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Yushchenko said outsiders should only work to ..." with entities "[(37, 48, 'LOC'), (120, 127, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The newspaper says and internal police security do..." with entities "[(31, 36, 'LOC'), (74, 81, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "They say 22 suspected insurgents have been detaine..." with entities "[(4, 14, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Authorities say Friday 's blast wounded 15 other p..." with entities "[(91, 98, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Germany has about 2,800 troops in Afghanistan as p..." with entities "[(0, 5, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Ukraine 's parliament speaker and the European Uni..." with entities "[(0, 7, 'LOC'), (34, 45, 'LOC'), (61, 65, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The Reuters news agency quotes a Paktia official a..." with entities "[(9, 24, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Baluchistan province experiences regular bombing a..." with entities "[(0, 7, 'LOC'), (38, 52, 'ORG'), (119, 125, 'MISC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Russian President Vladimir Putin has voiced strong..." with entities "[(8, 15, 'LOC'), (18, 25, 'LOC'), (72, 78, 'ORG'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Cuba has condemned the execution of former Iraqi d..." with entities "[(4, 11, 'ORG'), (33, 39, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Brown will meet with Mr. Obama Tuesday at the ..." with entities "[(0, 11, 'LOC'), (90, 96, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "He was convicted in the Netherlands six years ago ..." with entities "[(0, 7, 'MISC'), (18, 32, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The letter appeared in a Prague newspaper , the Ml..." with entities "[(0, 4, 'LOC'), (43, 48, 'MISC'), (58, 72, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Meanwhile , China 's foreign ministry says it is s..." with entities "[(4, 14, 'LOC'), (35, 37, 'PER'), (37, 40, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Panama also plans to construct a metro system in P..." with entities "[(4, 9, 'PER'), (29, 34, 'PER'), (50, 61, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Rescuers used ropes to help them wade through the ..." with entities "[(24, 35, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The U.S. government is expressing doubts about a t..." with entities "[(0, 7, 'PER'), (40, 44, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The announcement follows five days of protests by ..." with entities "[(25, 31, 'LOC'), (48, 65, 'ORG'), (85, 92, 'MISC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "On Wednesday , Pakistani officials said 10 paramil..." with entities "[(12, 17, 'LOC'), (57, 63, 'LOC'), (167, 171, 'LOC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Match referee Markus Merk of Germany had complaine..." with entities "[(0, 6, 'LOC'), (49, 60, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Russian troops have been battling separatists in C..." with entities "[(4, 11, 'PER'), (48, 49, 'LOC'), (50, 51, 'LOC'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Former world champion Marcus Gronholm of Finland i..." with entities "[(86, 91, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The death toll from southern Asia 's tsunami rose ..." with entities "[(4, 5, 'LOC'), (6, 7, 'LOC'), (70, 78, 'MISC'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Russia 's President Vladimir Putin was meeting Pre..." with entities "[(10, 17, 'LOC'), (20, 25, 'LOC'), (98, 114, 'PER'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "European Union Commission President Jose Manuel Ba..." with entities "[(50, 56, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The victims may have been trying to syphon fuel at..." with entities "[(15, 24, 'MISC'), (133, 139, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Two more children were wounded and taken to a U.S...." with entities "[(14, 25, 'PER'), (29, 36, 'LOC'), (57, 63, 'PER')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "China presented a draft statement Saturday , and U..." with entities "[(4, 5, 'LOC'), (6, 7, 'LOC'), (21, 25, 'LOC'), (3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The International Criminal Court has indicted five..." with entities "[(0, 7, 'MISC'), (49, 57, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The world 's largest drug company has agreed to pa..." with entities "[(22, 37, 'PER'), (41, 48, 'LOC'), (54, 61, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Those objections focus on preserving the military ..." with entities "[(29, 33, 'LOC'), (79, 88, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Brazilian Foreign Minister Celso Amorim made the s..." with entities "[(0, 6, 'LOC'), (20, 34, 'PER'), (57, 61, 'PER'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Helmand province has been badly affected by the Ta..." with entities "[(0, 25, 'ORG'), (36, 55, 'PER'), (71, 77, 'LOC'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Some indicators are not falling as fast as they ha..." with entities "[(8, 14, 'MISC'), (21, 66, 'ORG'), (82, 90, 'ORG')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Many others remain missing ." with entities "[(0, 11, 'MISC'), (26, 34, 'PER'), (67, 73, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The government 's land reform program , characteri..." with entities "[(46, 47, 'LOC'), (48, 49, 'LOC'), (80, 88, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Dutch police have raided a suspected training camp..." with entities "[(7, 8, 'ORG'), (9, 10, 'ORG'), (30, 40, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Padilla 's case has been the subject of numero..." with entities "[(0, 5, 'LOC'), (49, 50, 'LOC'), (51, 52, 'LOC'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The commission also said it needed time to work ou..." with entities "[(4, 32, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Still another government report showed U.S. consum..." with entities "[(0, 9, 'MISC'), (27, 39, 'PER'), (83, 89, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The suspects face charges that include " forming a..." with entities "[(0, 7, 'LOC'), (48, 55, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "It is generally observed by banks , the bond marke..." with entities "[(31, 40, 'MISC'), (51, 63, 'PER'), (63, 66, 'LOC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The report says that immigration has led to a " gl..." with entities "[(0, 5, 'MISC'), (54, 60, 'LOC'), (73, 98, 'ORG'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Media reports say Alperon was returning from a cou..." with entities "[(4, 11, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Authorities said Wednesday that the migrants , hop..." with entities "[(114, 125, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Islamic radicals stormed the U.S. Embassy on Novem..." with entities "[(0, 5, 'LOC'), (134, 140, 'MISC'), (158, 161, 'OR...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The strike has shut down New York 's huge subway a..." with entities "[(0, 6, 'ORG'), (23, 34, 'PER'), (57, 63, 'ORG'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Germany 's Sami Khedira scored in the 82nd minute ..." with entities "[(39, 40, 'LOC'), (41, 43, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "In China , official policy restricts couples in ur..." with entities "[(0, 5, 'PER'), (31, 36, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Several Democratic lawmakers sent a letter to the ..." with entities "[(5, 12, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Other hits include Blueberry Hill and Ai n't That ..." with entities "[(0, 9, 'MISC'), (108, 116, 'ORG'), (200, 209, 'LO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "No such weapons were found ." with entities "[(26, 31, 'LOC'), (76, 83, 'MISC'), (110, 118, 'MI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The U.S. military in Iraq says a roadside bomb has..." with entities "[(58, 72, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "That same day , U.S. troops shot dead an Italian i..." with entities "[(0, 9, 'MISC'), (43, 44, 'LOC'), (45, 46, 'LOC'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "His comments are in a report to the U.N. Security ..." with entities "[(18, 25, 'PER'), (75, 79, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Sri Lankan military officials say at least 18 Tami..." with entities "[(0, 7, 'MISC'), (29, 30, 'LOC'), (31, 32, 'LOC'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Brazil had the lead twice at the Frankenstadion , ..." with entities "[(4, 9, 'LOC'), (105, 112, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Cuba 's universal health care , the product of a c..." with entities "[(0, 6, 'LOC'), (16, 21, 'PER'), (21, 23, 'ORG'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Eight million Iraqis voted , but the country 's Su..." with entities "[(0, 2, 'MISC'), (2, 4, 'ORG'), (4, 5, 'MISC'), (6...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "UNICEF says it has begun moving additional staff a..." with entities "[(25, 33, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The station refused to air the entire tape for wha..." with entities "[(0, 7, 'LOC'), (11, 23, 'PER'), (56, 63, 'LOC'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Domination by Persians , Arabs , and Turks was fol..." with entities "[(3, 8, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The district is controlled by the Shi'ite Mahdi mi..." with entities "[(4, 25, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The report says the two , identified as Rachid Ilh..." with entities "[(8, 18, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "More than 30,000 people have died in the conflict ..." with entities "[(27, 52, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "An ongoing U.N. investigation has implicated top S..." with entities "[(27, 33, 'LOC'), (76, 82, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The mayor blames remnants of the Islamic courts mo..." with entities "[(19, 33, 'MISC'), (38, 42, 'MISC'), (43, 57, 'MIS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Human Rights Watch says many more incidents of rap..." with entities "[(4, 5, 'LOC'), (6, 7, 'LOC'), (21, 25, 'LOC'), (9...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The spokesman , Zemedkun Tekle , issued the denial..." with entities "[(16, 17, 'LOC'), (18, 19, 'LOC'), (41, 48, 'MISC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The U.S. military says it is searching with all av..." with entities "[(94, 101, 'MISC'), (115, 126, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Authorities say the boat 's maximum capacity was 6..." with entities "[(36, 37, 'ORG'), (38, 57, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Lashkar has not commented on the army statement ." with entities "[(0, 11, 'LOC'), (15, 21, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "They say the bomb blast occurred in eastern Baghda..." with entities "[(0, 10, 'MISC'), (46, 51, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "He knocked at the door and inquired of the inmates..." with entities "[(0, 6, 'LOC'), (33, 47, 'LOC'), (54, 61, 'LOC'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Pakistani officials say the senior officer heading..." with entities "[(52, 61, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The Pakistan government has proposed a controversi..." with entities "[(14, 19, 'MISC'), (48, 53, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mitchell said voters should hold the Bush administ..." with entities "[(0, 6, 'ORG'), (67, 75, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Sarkozy said a French citizen who suddenly goe..." with entities "[(4, 7, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Organizers say the torch will still travel through..." with entities "[(14, 21, 'MISC'), (25, 30, 'MISC'), (37, 42, 'MIS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Late Wednesday , the rival Hamas party registered ..." with entities "[(4, 13, 'PER'), (23, 27, 'ORG'), (64, 68, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The releases were announced Saturday ." with entities "[(34, 37, 'MISC'), (38, 40, 'MISC'), (42, 55, 'ORG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "A coalition of Iraq 's majority Shi'ite Muslims ha..." with entities "[(40, 53, 'PER'), (58, 74, 'PER'), (152, 157, 'LOC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "None of the political groups won the 163 seats nee..." with entities "[(11, 12, 'ORG'), (13, 14, 'ORG'), (49, 55, 'MISC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Human Rights Watch issued a statement late Tuesday..." with entities "[(33, 40, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "However , the presidential spokesman says Presiden..." with entities "[(0, 18, 'ORG'), (89, 94, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Violence has declined during the winter ." with entities "[(16, 30, 'PER'), (87, 119, 'ORG'), (195, 203, 'LO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "But , he said , this is a very hard problem and th..." with entities "[(4, 5, 'LOC'), (6, 7, 'LOC'), (71, 72, 'LOC'), (7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "A referendum would have delayed the withdrawal for..." with entities "[(4, 9, 'MISC'), (16, 52, 'ORG'), (107, 108, 'MISC...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The Pentagon says seven detainees at the U.S. mili..." with entities "[(0, 7, 'LOC'), (63, 64, 'MISC'), (65, 67, 'MISC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "More than 100 people were killed ." with entities "[(28, 33, 'MISC'), (80, 85, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Rising oil prices , global trade imbalances and Ch..." with entities "[(44, 61, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Reid also said the president should pledge not..." with entities "[(44, 51, 'LOC'), (55, 61, 'MISC'), (63, 72, 'LOC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Candidates associated with the banned Muslim Broth..." with entities "[(0, 6, 'LOC'), (15, 24, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Switzerland has also come under increasing pressur..." with entities "[(0, 9, 'MISC'), (104, 113, 'MISC'), (129, 143, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Interpol said the raided shops had handled bets to..." with entities "[(4, 12, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Earlier Tuesday , Haiti 's chief elections officia..." with entities "[(0, 8, 'PER'), (37, 41, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Lieutenant Nathan Perry Monday told VOA that U.S. ..." with entities "[(47, 54, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Relations between the two countries have been stra..." with entities "[(4, 11, 'PER'), (19, 25, 'MISC'), (55, 66, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# ...
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Indian Home Minister P. Chidambaram Tuesday warned..." with entities "[(18, 25, 'MISC'), (79, 108, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Nobody was injured in the blasts ." with entities "[(32, 42, 'MISC'), (53, 57, 'LOC'), (84, 90, 'LOC'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Palestinian sources say there were no casualties ." with entities "[(4, 6, 'ORG'), (51, 56, 'LOC'), (108, 124, 'PER')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Senator McCain wants Congress to lift a ban on off..." with entities "[(0, 8, 'LOC'), (43, 50, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Canadian authorities said Monday the duck did not ..." with entities "[(20, 28, 'LOC'), (102, 113, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Iran 's civil aviation organization says it has as..." with entities "[(17, 31, 'PER'), (50, 59, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Tuesday , Washington recalled its ambassador to Sy..." with entities "[(60, 67, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Lantos says the officials told him they suppor..." with entities "[(4, 11, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Somalia 's transitional government has announced p..." with entities "[(45, 50, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Khost Governor Arsala Jamal says the Taleban milit..." with entities "[(0, 6, 'MISC'), (66, 72, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The signs have displayed human rights sayings of t..." with entities "[(17, 21, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Bush made the comments in his weekly radio add..." with entities "[(49, 52, 'MISC'), (115, 120, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "It has accused Tehran of backing insurgents fighti..." with entities "[(0, 8, 'LOC'), (45, 59, 'ORG'), (102, 108, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Cuban President Raul Castro says he is open to dir..." with entities "[(16, 29, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The third rocket landed about 15 kilometers away ,..." with entities "[(0, 7, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Earlier this month , North Korea agreed to close i..." with entities "[(4, 10, 'MISC'), (22, 27, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Top U.S. and Japanese negotiators in nuclear disar..." with entities "[(76, 85, 'MISC'), (90, 94, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Bird flu has spread across parts of Europe , Afric..." with entities "[(0, 7, 'PER'), (79, 85, 'PER'), (89, 96, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Tehran says its nuclear program is only for peacef..." with entities "[(14, 21, 'LOC'), (38, 44, 'PER'), (79, 85, 'PER')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "A coalition and an Afghan soldier were also killed..." with entities "[(4, 5, 'LOC'), (6, 7, 'LOC'), (86, 92, 'LOC'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Bush left Saturday for his next stop in Brazil..." with entities "[(12, 19, 'MISC'), (35, 47, 'PER'), (108, 120, 'MI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Russian Defense Minister Sergei Ivanov says Moscow..." with entities "[(0, 9, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Earlier , the Iranian Foreign Ministry confirmed t..." with entities "[(0, 2, 'ORG'), (35, 56, 'PER'), (72, 80, 'LOC'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "West Virginia is the state where 12 miners died af..." with entities "[(0, 7, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "In Mosul , authorities say three Iraqis were kille..." with entities "[(5, 14, 'PER'), (73, 79, 'MISC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "They say several others were wounded when rebels r..." with entities "[(4, 11, 'MISC'), (24, 33, 'ORG'), (87, 94, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "She meets with Palestinian leader Mahmoud Abbas Mo..." with entities "[(0, 8, 'MISC'), (27, 43, 'MISC'), (73, 80, 'LOC')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Mr. Chirac has not endorsed a candidate for next m..." with entities "[(22, 29, 'MISC'), (49, 53, 'LOC'), (118, 123, 'MI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The vast majority of candidates in the local elect..." with entities "[(4, 10, 'ORG'), (64, 79, 'PER'), (91, 99, 'PER'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Over the weekend , the Group of Seven Industrializ..." with entities "[(0, 6, 'MISC'), (24, 47, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "Top U.S. officials had warned the pastor that the ..." with entities "[(27, 32, 'LOC')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "He said he will review the issue in the " national..." with entities "[(4, 8, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,
# /home/jaidevd/conda/lib/python3.7/site-packages/spacy/training/iob_utils.py:144: UserWarning: [W030] Some entities could not be aligned in the text "The Iranian news agency quotes Mr. Ahmadinejad as ..." with entities "[(0, 5, 'PER')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   entities=ent_str[:50] + "..." if len(ent_str) > 50 else ent_str,

# %%
from datasets import load_metric

# %%
metric = load_metric('seqeval')

# %%
metric.compute(predictions=ent_pred_tags, references=ent_true_tags, zero_division="warn", average="micro")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_41590/460500031.py in <module>
# ----> 1 metric.compute(predictions=ent_pred_tags, references=ent_true_tags, zero_division="warn", average="micro")
#
# ~/conda/lib/python3.7/site-packages/datasets/metric.py in compute(self, predictions, references, **kwargs)
#     428             inputs = {input_name: self.data[input_name] for input_name in self.features}
#     429             with temp_seed(self.seed):
# --> 430                 output = self._compute(**inputs, **compute_kwargs)
#     431
#     432             if self.buf_writer is not None:
#
# TypeError: _compute() got an unexpected keyword argument 'average'

# %%
from itertools import chain

# %%
set(chain(*ent_pred_tags))
# Out:
# {'-',
#  'B-LOC',
#  'B-MISC',
#  'B-ORG',
#  'B-PER',
#  'I-LOC',
#  'I-MISC',
#  'I-ORG',
#  'I-PER',
#  'O'}

# %%
set(chain(*ent_true_tags))
# Out:
# {'B-ART',
#  'B-EVE',
#  'B-GEO',
#  'B-GPE',
#  'B-NAT',
#  'B-ORG',
#  'B-PER',
#  'B-TIM',
#  'I-ART',
#  'I-EVE',
#  'I-GEO',
#  'I-GPE',
#  'I-ORG',
#  'I-PER',
#  'I-TIM',
#  'O'}

# %%
with open('/tmp/e.json', 'r') as fin:
    tweets = [json.loads(k) for k in fin.readlines()]

# %%
from spacy.training import biluo_tags_to_offsets

def parse(text, entities, annotation_offsets, **kwargs):
    doc = nlp(text)
    return biluo_tags_to_offsets(doc, entities)

for tweet in tweets:
    ents = parse(**tweet)
    doc = nlp(tweet['text'])
    entities = tweet['entities']
    break

# %%
biluo_tags_to_offsets(doc, entities)
# Out:
# []

# %%
entities
# Out:
# ['O',
#  'B-ORG',
#  'I-ORG',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-LOC',
#  'I-LOC',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B-LOC',
#  'O',
#  'O']

# %%
doc
# Out:
# #BREAKINGNEWS MALAYSIA AIRLINES FLIGHT #MH17 CONFIRMED SHOT DOWN OVER #DONETSK OBLAST, SHORTLY BEFORE REACHING RUSSIAN AIR SPACE

# %%
len(doc)
# Out:
# 21

# %%
len(entities)
# Out:
# 18

# %%
ent_clean = []
for label, (start, end) in zip(tweet['entities'], tweet['annotation_offsets']):
    if label == 'O':
        continue
    span = doc.char_span(start, end)
    print(span, label)
    ent_clean.append(span)
# Out:
# MALAYSIA B-ORG
# AIRLINES I-ORG
# #DONETSK B-LOC
# OBLAST I-LOC
# RUSSIAN B-LOC

# %%
from spacy.util import filter_spans

# %%
filter_spans(ent_clean)
# Out:
# [MALAYSIA, AIRLINES, #DONETSK, OBLAST, RUSSIAN]

# %%
filter_spans?
# Out:
# Signature: filter_spans(spans: Iterable[ForwardRef('Span')]) -> List[ForwardRef('Span')]
# Docstring:
# Filter a sequence of spans and remove duplicates or overlaps. Useful for
# creating named entities (where one token can only be part of one entity) or
# when merging spans with `Retokenizer.merge`. When spans overlap, the (first)
# longest span is preferred over shorter spans.
#
# spans (Iterable[Span]): The spans to filter.
# RETURNS (List[Span]): The filtered spans.
# File:      ~/conda/lib/python3.7/site-packages/spacy/util.py
# Type:      function
